# %%
import osmium
import re

import geopandas as gpd
import pandas as pd
import numpy as np

from geopy.geocoders import Nominatim

from collections import defaultdict

# %%
class WayHandler(osmium.SimpleHandler):

    def __init__(self):
        osmium.SimpleHandler.__init__(self)
        self.id = []
        self.tag = []
        self.height = []
        self.min_height = []

        self.LEVEL_HEIGHT = 3.4

    # https://wiki.openstreetmap.org/wiki/Simple_3D_buildings#Other_roof_tags
    def _feet_to_meters(self, s):
        r = re.compile("([0-9]*\.?[0-9]+)'([0-9]*\.?[0-9]+)?\"?")
        m = r.findall(s)[0]
        if len(m[0]) > 0 and len(m[1]) > 0:
            m = float(m[0]) + float(m[1]) / 12.0
        elif len(m[0]) > 0:
            m = float(m[0])
        return m * 0.3048

    def _get_height(self, tags):
        if 'height' in tags:
            # already accounts for roof
            if '\'' in tags['height'] or '\"' in tags['height']:
                return self._feet_to_meters(tags['height'])
            r = re.compile(r"[-+]?\d*\.\d+|\d+")
            return float(r.findall(tags['height'])[0])
        if 'levels' in tags:
            roof_height = 0
            if 'roof_height' in tags:
                if '\'' in tags['roof_height'] or '\"' in tags['roof_height']:
                    roof_height = self._feet_to_meters(tags['roof_height'])
                else:
                    r = re.compile(r"[-+]?\d*\.\d+|\d+")
                    roof_height = float(r.findall(tags['roof_height'])[0])

            # does not account for roof height
            height = float(tags['levels']) * self.LEVEL_HEIGHT
            if 'roof_levels' in tags and roof_height == 0:
                height += float(tags['roof_levels']) * self.LEVEL_HEIGHT
            return height

        return 7.0 # Should I return N/A -> Ask professor!!

    def _get_min_height(self, tags):
        if 'min_height' in tags:
            # already accounts for roof
            if '\'' in tags['min_height'] or '\"' in tags['min_height']:
                return self._feet_to_meters(tags['min_height'])
            r = re.compile(r"[-+]?\d*\.\d+|\d+")
            return float(r.findall(tags['min_height'])[0])
        if 'min_level' in tags:
            height = float(tags['min_level']) * self.LEVEL_HEIGHT
            return height
        return 0.0
        
    def get_df(self):
        height = pd.Series(self.height, dtype='float')
        min_height = pd.Series(self.min_height, dtype='float')
        tag = pd.Series(self.tag)
        iid = pd.Series(self.id, dtype='UInt64')
        
        return pd.DataFrame({
            'id': iid,
            'min_height': min_height,
            'height': height,
            'tags': tag
        })
    
    def way(self, w):
        tags = dict(w.tags)
        id = int(w.id)
        
        # Qualifiers
        if not ('building' in tags or 'building:part' in tags or tags.get('type') == 'building'):
            return
        # Disqualifiers
        if (tags.get('location') == 'underground' or 'bridge' in tags):
            return

        # pointList = []
        # for p in list(w.nodes):
        #     pointList.append(geometry.Point(p.lat, p.lon))
        # poly = geometry.Polygon([[p.lat, p.lon] for p in pointList])

        # print(poly.wkt)

        # Manage way and relation together
        
        try:
            height = self._get_height(tags)
            min_height = self._get_min_height(tags)
            self.height.append(height)
            self.min_height.append(min_height)
            self.tag.append(tags)
            self.id.append(id)
            
        except Exception as e:
            print(e)
            print(w)

# %%
h = WayHandler()
h.apply_file('data/osm/rec.osm.pbf', locations=True)
df = h.get_df()
df
# Out:
#                 id  min_height  height  \
# 0         51816211         0.0     7.0
# 1         51816216         0.0     7.0
# 2         51816217         0.0    13.0
# 3         51816218         0.0     7.0
# 4         51816220         0.0     7.0
# ...            ...         ...     ...
# 140362  1064791239         0.0     7.0
# 140363  1064791240         0.0     7.0
# 140364  1070775598         0.0     7.0
# 140365  1071164414         0.0     7.0
# 140366  1071828237         0.0     7.0
#
#                                                      tags
# 0       {'addr:housename': 'Armazém 12', 'building': '...
# 1       {'building': 'yes', 'building:levels': '5', 'n...
# 2       {'addr:city': 'Recife', 'addr:housenumber': '3...
# 3       {'addr:city': 'Recife', 'addr:housenumber': '1...
# 4       {'addr:housename': 'Armazém 13', 'building': '...
# ...                                                   ...
# 140362  {'building': 'apartments', 'building:levels': ...
# 140363                         {'building': 'apartments'}
# 140364  {'addr:city': 'Recife', 'addr:housenumber': '1...
# 140365  {'addr:street': 'Rua Trinta e Nove', 'amenity'...
# 140366                          {'building': 'warehouse'}
#
# [140367 rows x 4 columns]

# %%
# Gather all tags of current recife buildings into a list
all_tags = []
mp = defaultdict(lambda: 0)
for tag in df['tags']:
    for key in tag:
        if(not mp[key] and key != 'height' and key != 'min_height'):
            mp[key] = 1
            all_tags.append(key)
all_tags.sort()

# %%
df = df.reindex(columns=[*df.columns.tolist(), *all_tags], fill_value=np.nan) # Add all tags as separate pandas column with default value nan

# Check if tag has value for a building. If so, add it to its corresponding new column
n = len(df)
for i in range(n):
    tags = df.iloc[i]['tags']

    for key in tags:
        df.at[i, key] = tags[key]

# %%
df.drop(columns=['tags'], inplace=True)
df.to_csv('all-building-features.csv') # Save in a csv file

# %%
# count of how many building has such tags in recife
n = len(df)
tag_counts = df.isnull().sum(axis = 0)
for tag, counts in tag_counts.iteritems():
    print(tag, n - counts)
# Out:
# id 140740
# orig_id 140740
# building_id 140740
# geometry 140740
# min_height 140740
# height 140740
# PrefRecife:escola_codigo 16
# PrefRecife:escola_tipo 16
# PrefRecife:mec_codigo 16
# abandoned 1
# abandoned:building 2
# access 37
# addr:city 2354
# addr:flats 14
# addr:hamlet 1
# addr:housename 31
# addr:housenumber 10567
# addr:place 14
# addr:postcode 1236
# addr:street 11535
# addr:suburb 2251
# addr:unit 14
# admin_level 1
# advertising 1
# aeroway 24
# air_conditioning 37
# alt_name 170
# amenity 1306
# animal 18
# architect 3
# area 11
# area:highway 3
# artist_name 1
# artwork_type 4
# atm 13
# attraction 8
# automated 2
# baby_feeding 2
# bar 2
# barrier 2
# bench 2
# branch 1
# brand 245
# brand:wikidata 241
# brand:wikipedia 234
# brewery 7
# building 140708
# building:colour 153
# building:flats 17
# building:levels 1272
# building:material 31
# building:min_level 4
# building:part 356
# building_1 4
# bus 67
# capacity 10
# capacity:disabled 4
# capacity:persons 1
# castle_type 2
# changing_table 3
# clothes 4
# club 8
# construction 15
# consulate 2
# contact:email 1
# contact:facebook 2
# contact:instagram 1
# contact:phone 2
# contact:website 2
# content 13
# country 3
# covered 7
# craft 10
# cuisine 48
# dance:style 1
# dance:teaching 1
# delivery 7
# denomination 98
# departures_board 1
# description 114
# diet:vegetarian 2
# diplomatic 3
# dispensing 74
# disused 4
# disused:building 1
# disused:railway 1
# disused:shop 1
# drive_through 10
# email 28
# emergency 12
# fax 4
# fee 6
# female 1
# ferry 1
# fixme 6
# floating 72
# floor:material 1
# fuel:diesel 2
# fuel:octane_87 11
# garden:style 1
# garden:type 1
# government 12
# healthcare 203
# healthcare:speciality 13
# highway 27
# historic 20
# historic:civilization 2
# house 10
# image 1
# indoor 1
# industrial 9
# information 1
# inscription 4
# internet_access 46
# internet_access:fee 11
# landuse 49
# layer 416
# leisure 65
# level 28
# light_rail 2
# lit 6
# livestock 1
# location 2
# male 1
# man_made 122
# mapillary 21
# material 5
# microbrewery 2
# military 25
# museum 4
# name 2755
# name:en 33
# name:es 1
# name:fr 1
# name:pt 31
# name:signed 2
# name:uk 1
# name:zh 1
# name_1 2
# network 12
# nohousenumber 2
# not:brand:wikidata 1
# not:operator:wikidata 1
# note 11
# office 126
# official_name 7
# old_name 10
# opening_date 1
# opening_hours 167
# opening_hours:covid19 17
# opening_hours:signed 2
# operator 144
# operator:en 2
# operator:short 11
# operator:type 9
# operator:wikidata 27
# operator:wikipedia 26
# organic 5
# outdoor_seating 4
# parking 42
# parts 1
# payment:bitcoin 2
# payment:cards 1
# payment:cash 27
# payment:coins 3
# payment:credit_cards 24
# payment:debit_cards 12
# payment:diners_club 1
# payment:maestro 3
# payment:mastercard 8
# payment:nfc 1
# payment:pix 1
# payment:visa 10
# payment:visa_debit 2
# payment:visa_electron 4
# phone 328
# phone_1 7
# polling_station 1
# postal_code 4
# poultry 1
# produce 18
# product 1
# proposed 1
# public_transport 85
# public_transport_1 1
# railway 17
# ref 118
# religion 229
# reservation 1
# residential 9
# roof:colour 250
# roof:direction 73
# roof:height 75
# roof:levels 162
# roof:material 79
# roof:shape 234
# roof:type 8
# rooms 3
# ruins 1
# seamark:building:function 12
# seamark:fortified_structure:category 3
# seamark:landmark:category 1
# seamark:landmark:function 11
# seamark:tank:category 11
# seamark:type 26
# second_hand 7
# self_service 14
# service 1
# service:bicycle:Bicycle_Sales_and_Service 1
# service:bicycle:accessoires 1
# service:bicycle:bicycle 1
# service:bicycle:repair 1
# service:bicycle:sales 1
# service:bicycle:service 1
# service:vehicle:Retificadora 1
# service:vehicle:car_repair 2
# service:vehicle:diagnostics 1
# service:vehicle:inspection 2
# service:vehicle:new_car_sales 2
# service:vehicle:oil_change 1
# service:vehicle:repairs 1
# service:vehicle:used_car_sales 2
# service_times 5
# shelter 5
# shelter_type 92
# shoes 1
# shop 2242
# short_name 32
# smoking 13
# social_facility 1
# social_facility:for 1
# source 12933
# source:date 18
# source:postal_code 1
# sport 11
# stars 1
# start_date 16
# station 18
# stroller 18
# studio 3
# subway 17
# supervised 3
# surface 19
# survey:date 22
# takeaway 17
# target 2
# telecom 1
# theatre:type 1
# toilets 1
# toilets:access 2
# toilets:disposal 1
# toilets:handwashing 1
# toilets:wheelchair 2
# tourism 97
# tower:type 1
# townhall:type 1
# train 1
# tram 1
# tunnel 1
# type 4
# unisex 13
# waste 2
# website 232
# wheelchair 218
# wholesale 2
# wikidata 48
# wikipedia 36
