# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
from extract_linestrings import *

# %%
### After the sidewalk data is processed and cleaned we can extract dir and indir indicators using notebook 1 and 2

# %% [markdown]
# ### Extract sidewalk data

# %%
h = WayHandler()
h.apply_file("data/osm/chi.osm.pbf", locations = True)

# %%
# chi_st_network = h.get_gdf(road_qualifier)
# chi_footway = h.get_gdf(footway_qualifier)
# chi_sidewalk = h.get_gdf(sidewalk_qualifer)
# chi_crossings = h.get_gdf(road_crossing_qualifer)
# chi_roads_w_sidewalk = h.get_gdf(roads_with_sidewalk_qualifier)
sidepath_road_tag = h.get_gdf(unspec)

# %%
sidepath_road_tag.iloc[0].tags
# Out:
# {'highway': 'secondary',
#  'lanes': '2',
#  'name': 'East Grand Avenue',
#  'oneway': 'yes',
#  'sidewalk:left': 'no',
#  'sidewalk:right': 'separate',
#  'surface': 'asphalt'}

# %%
print(True or False and False)
# Out:
# True

# %%
# m = chi_sidewalk.explore(tiles = 'CartoDB positron')
# m.save('sidewalk.html')

# %%
# dtown = chi_st_network.cx[-87.643842:-87.614230, 41.875:41.89]
# dtown_sidewalks = chi_sidewalks.cx[-87.623842:-87.614230, 41.875:41.89]

# %%
# fig, ax = plt.subplots(figsize = (30,30)) 
# dtown.plot(ax=ax)
# dtown_sidewalks.plot(color = '#ED1C24', ax=ax, lw = 1.5, ls = '--' )
# Out:
#                id                                               tags osm_type  \
# 0         4476710  {'highway': 'secondary', 'lanes': '2', 'name':...        W
# 1         4477283  {'highway': 'primary', 'loc_ref': '200 S', 'na...        W
# 2         4477285  {'highway': 'secondary', 'lanes': '3', 'loc_re...        W
# 3         5010709  {'highway': 'secondary', 'loc_ref': '100 E', '...        W
# 4         5010711  {'highway': 'secondary', 'lanes': '4', 'loc_re...        W
# ...           ...                                                ...      ...
# 42694  1083601826      {'footway': 'sidewalk', 'highway': 'footway'}        W
# 42695  1083603296  {'footway': 'sidewalk', 'highway': 'footway', ...        W
# 42696  1083603297  {'footway': 'sidewalk', 'highway': 'footway', ...        W
# 42697  1083603298  {'footway': 'sidewalk', 'highway': 'footway', ...        W
# 42698  1083603299  {'footway': 'sidewalk', 'highway': 'footway', ...        W
#
# ...
